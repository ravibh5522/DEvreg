# %%
import numpy as numpy
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('rawdata.csv')
# Out:
# C:\Users\ravib\AppData\Local\Temp\ipykernel_6588\2867232935.py:1: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('rawdata.csv')

# %%
df
# Out:
#                                     reviewId              userName  \
# 0       68ccaec8-1415-4301-a85e-3004679a3a83          Cassie Moore
# 1       d84cbfd3-6aa3-485c-aaf9-c5dca27dc966         Kaleb Plummer
# 2       96618aa1-31e5-4259-8649-89b75d962f00           Rylee Maher
# 3       078c0bda-598b-474e-a04e-d7cb3e6f6301  Kittykatelyn Romilly
# 4       8e68c5cd-b12a-4206-a8da-6bfdbff44ae3      Loveness Malenga
# ...                                      ...                   ...
# 460282  73cf78fe-599d-4488-8a8b-ae443847303b           hera killar
# 460283  16d331c8-ba21-4aeb-ac01-dec455ca48ad        Hiox Softwares
# 460284  fbb86777-b885-4f76-b49e-13e424aa5afc       Md. Zahid Hasan
# 460285  28df682c-bb17-4224-8658-642a92a2c723              Ash Ryan
# 460286  1cfbb2b3-fb0b-4f4b-8963-9e2b803f24dc           Haroon Jaan
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/ALm5wu...
# ...

# %%
# delete row reviewid
df.drop(['thumbsUpCount','reviewCreatedVersion'], axis=1, inplace=True)

# %%
df
# Out:
#                     userName  \
# 0               Cassie Moore
# 1              Kaleb Plummer
# 2                Rylee Maher
# 3       Kittykatelyn Romilly
# 4           Loveness Malenga
# ...                      ...
# 460282           hera killar
# 460283        Hiox Softwares
# 460284       Md. Zahid Hasan
# 460285              Ash Ryan
# 460286           Haroon Jaan
#
#                                                   content                   at
# 0                                                No words  2022-11-29 21:55:37
# 1                                   Great fun app so far!  2022-11-29 21:55:04
# 2       The app would get a higher rating but I litera...  2022-11-29 21:54:48
# 3       I WISH I COULD GIVE THIS A 100 PERCENT RATING ...  2022-11-29 21:54:35
# 4                                     Pictures and record  2022-11-29 21:54:21
# ...                                                   ...                  ...
# ...

# %%
#delete row in content colum which contains less than 3 words
df2=df

# %%
df['word_count'] = df['content'].apply(lambda x: len(str(x).split(' ')))
df = df[df['word_count'] >= 3]

# %%
#new colum for sentiment analysis

# %%
df
# Out:
#                     userName  \
# 1              Kaleb Plummer
# 2                Rylee Maher
# 3       Kittykatelyn Romilly
# 4           Loveness Malenga
# 5            Melvin Crawford
# ...                      ...
# 460277          Calon Jansen
# 460278        RASAKI MURIANO
# 460281           Bff Mavneet
# 460285              Ash Ryan
# 460286           Haroon Jaan
#
#                                                   content  \
# 1                                   Great fun app so far!
# 2       The app would get a higher rating but I litera...
# 3       I WISH I COULD GIVE THIS A 100 PERCENT RATING ...
# 4                                     Pictures and record
# 5                                 I love this amazing app
# ...                                                   ...
# 460277  I like the experience of advertising your tale...
# 460278                             I'm really enjoying it
# 460281                                          I love it
# ...

# %%
#copy d3 75 rows to new dataframe
df=pd.read_csv('cldata.csv')
df3 = df.head(75).copy()

# %%
import json
dfj=pd.read_json('tune.json')

# %%
dfj = dfj.head(75).copy()
dfj
# Out:
#     index    sentiment              summary
# 0       1      neutral                   NA
# 1       2     positive            Great app
# 2       3  bugCritical        Sign-in issue
# 3       4     positive   100 percent rating
# 4       5      neutral                   NA
# ..    ...          ...                  ...
# 70     71     positive                 nice
# 71     72     positive  My Favourite TikTok
# 72     73     positive                 Good
# 73     74     positive          That's nice
# 74     75      request  Dream 20k followers
#
# [75 rows x 3 columns]

# %%
df3
# Out:
#     Unnamed: 0.1  Unnamed: 0  \
# 0              0           0
# 1              1           1
# 2              2           2
# 3              3           3
# 4              4           4
# ..           ...         ...
# 70            70          70
# 71            71          71
# 72            72          72
# 73            73          73
# 74            74          74
#
#                                              userName  \
# 0                                        Cassie Moore
# 1                                       Kaleb Plummer
# 2                                         Rylee Maher
# 3                                Kittykatelyn Romilly
# 4                                    Loveness Malenga
# ..                                                ...
# 70  ÃÂ§ÃÂÃÂ®ÃÂÃÂÃÂ¿ÃÂ ÃÂÃÂÃÂµÃÂºÃ...
# 71                                       Shahab Kings
# 72                                      Pardesi Munda
# 73                                        Gulzar Khan
# ...

# %%
#drop Unnamed: 0.1	and unamed: 0
df3.drop(['Unnamed: 0','Unnamed: 0.1'], axis=1, inplace=True)

# %%
df3
# Out:
#                                              userName  \
# 0                                        Cassie Moore
# 1                                       Kaleb Plummer
# 2                                         Rylee Maher
# 3                                Kittykatelyn Romilly
# 4                                    Loveness Malenga
# ..                                                ...
# 70  ÃÂ§ÃÂÃÂ®ÃÂÃÂÃÂ¿ÃÂ ÃÂÃÂÃÂµÃÂºÃ...
# 71                                       Shahab Kings
# 72                                      Pardesi Munda
# 73                                        Gulzar Khan
# 74                                     Elimu Endelevu
#
#                                               content                   at
# 0                                          "No words"  2022-11-29 21:55:37
# 1                             "Great fun app so far!"  2022-11-29 21:55:04
# 2   "The app would get a higher rating but I liter...  2022-11-29 21:54:48
# ...

# %%
#concanate dfj and df3
df4 = pd.concat([df3, dfj], axis=1)

# %%
#drop index column
df4.drop(['index'], axis=1, inplace=True)

# %%
df4
# Out:
#                                              userName  \
# 0                                        Cassie Moore
# 1                                       Kaleb Plummer
# 2                                         Rylee Maher
# 3                                Kittykatelyn Romilly
# 4                                    Loveness Malenga
# ..                                                ...
# 70  ÃÂ§ÃÂÃÂ®ÃÂÃÂÃÂ¿ÃÂ ÃÂÃÂÃÂµÃÂºÃ...
# 71                                       Shahab Kings
# 72                                      Pardesi Munda
# 73                                        Gulzar Khan
# 74                                     Elimu Endelevu
#
#                                               content                   at  \
# 0                                          "No words"  2022-11-29 21:55:37
# 1                             "Great fun app so far!"  2022-11-29 21:55:04
# 2   "The app would get a higher rating but I liter...  2022-11-29 21:54:48
# ...

# %%
#save to csv
df4.to_csv('tune.csv')
